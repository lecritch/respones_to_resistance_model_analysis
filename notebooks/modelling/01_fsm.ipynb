# %% [markdown]
# # FSM
#
# In this notebook, I work towards generating my FSM.
#
# I will first try either a logistic regression or random forest classifier where I naivly put features into the model.
#
# Then I will try modelling a subset of the data, just taking into account deomographic features.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, recall_score, confusion_matrix, precision_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler

parent_dir = '../../'

from IPython.display import display
pd.options.display.max_columns = None

# %% [markdown]
# ## Model Preparation
#
# First, let's drop all columns that don't make sense to model:

# %%
# import cleaned data so far:
prr_df = pd.read_csv(parent_dir + 'data/modified_data/prr19_cleaned', index_col = 0)
prr_df.head()
# Out:
#    objectid      zip     file_num       uof_num         date_occured  \
# 0      2817  75253.0  UF2019-1702  62295, 63542  2019-12-01 00:00:00
# 1      2234  75208.0  UF2019-1344         61093  2019-10-06 00:00:00
# 2      2755  75231.0  UF2019-1665         62820  2019-12-31 00:00:00
# 3      2110  75228.0  UF2019-1314         60990  2019-09-30 00:00:00
# 4      1663  75051.0  UF2019-1030  59592, 59600  2019-08-04 00:00:00
#
#           time_occured  current_ba off_sex  off_race            hire_date  \
# 0  2020-08-04 22:34:00       11285    Male     White  2017-03-08 00:00:00
# 1  2020-08-04 00:50:00       11208    Male     White  2016-08-24 00:00:00
# 2  2020-08-04 23:37:00        9415    Male     White  2008-04-02 00:00:00
# 3  2020-08-04 18:20:00        9884    Male  Hispanic  2009-06-10 00:00:00
# 4  2020-08-04 00:10:00       10480    Male  Hispanic  2012-09-26 00:00:00
#
#    off_injured                 off_cond_type  off_hospital    service_type  \
# 0        False  No injuries noted or visible         False    Service Call
# 1         True  No injuries noted or visible         False          Arrest
# 2        False  No injuries noted or visible         False          Arrest
# 3        False  No injuries noted or visible         False  Call for Cover
# 4         True  No injuries noted or visible         False          Arrest
#
#                      uof_type       uof_reason cycles_num uof_effective  \
# 0  BD - Tripped, BD - Grabbed  Detention/Frisk        NaN      Yes, Yes
# 1           Held Suspect Down           Arrest        NaN           Yes
# 2              K-9 Deployment           Arrest        NaN           Yes
# 3                 Joint Locks           Arrest        NaN           Yes
# 4   Joint Locks, BD - Grabbed           Arrest        NaN      Yes, Yes
#
#    street_n     street street_g street_t                 address     cit_num  \
# 0       102   Beltline        S      Rd.      102 S Beltline Rd.       60833
# 1      1500  Oak Cliff        S    Blvd.  1500 S Oak Cliff Blvd.  6020748798
# 2      6904    Walling      NaN      Ln.        6904 Walling Ln.       61130
# 3     11760   Ferguson      NaN      Rd.      11760 Ferguson Rd.       26625
# 4      1350    Skyline      NaN      Rd.        1350 Skyline Rd.       59513
#
#    cit_race cit_sex  cit_injured                 cit_cond_type  cit_arrest  \
# 0     White    Male        False  No injuries noted or visible       False
# 1  Hispanic  Female         True      Injured prior to contact        True
# 2     Black    Male         True                          Bite        True
# 3     White  Female        False  No injuries noted or visible        True
# 4     Black    Male        False  No injuries noted or visible        True
#
#    cit_influence                             cit_charge_type council_district  \
# 0       Agitated                                   No Arrest               D8
# 1       Agitated                                       APOWW               D1
# 2   Poor hygiene           Burglary/Habitation, Warrant/Hold               D9
# 3  Unknown Drugs  Assault/FV, Resisting Arrest, Warrant/Hold               D9
# 4       Agitated                      Assault/Public Servant              NaN
#
#        ra   beat  sector   division            x            y  \
# 0  6062.0  357.0   350.0  SOUTHEAST  2557123.437  6944231.397
# 1  4160.0  444.0   440.0  SOUTHWEST  2474936.793  6952151.398
# 2  6034.0  247.0   240.0  NORTHEAST  2508349.267  7001784.466
# 3  1132.0  228.0   220.0  NORTHEAST  2536678.324  6999039.025
# 4     NaN    NaN     NaN        NaN  2433285.622  6953645.720
#
#                     geolocation  council_districts_test  \
# 0  POINT (-96.586265 32.702825)                     8.0
# 1  POINT (-96.853036 32.729136)                     1.0
# 2  POINT (-96.741661 32.863941)                    13.0
# 3  POINT (-96.649175 32.855492)                    13.0
# 4   POINT (-96.98722 32.734935)                     NaN
#
#    dallas_city_limis_gis_layer
# 0                          3.0
# 1                          3.0
# 2                          3.0
# 3                          3.0
# 4                          NaN

# %% [markdown]
# To begin with, let's assume location isn't a factor - it most likely is, but for this model, let's not base our model off location, other than zipcode.
#
# So let's drop:
# - x
# - y
# - geolocation
# - council_districts_test
# - dallas_city_limis_gis_layer
# - street_n
# - street
# - street_g
# - street_t
# - address

# %%
cols_to_drop = ['x', 'y', 'geolocation', 'council_districts_test', 'dallas_city_limis_gis_layer', 'street_n', 
               'street', 'street_g', 'street_t', 'address']

# %%
prr_new = prr_df.drop(cols_to_drop, axis = 1)

# %%
prr_new.head()
# Out:
#    objectid      zip     file_num       uof_num         date_occured  \
# 0      2817  75253.0  UF2019-1702  62295, 63542  2019-12-01 00:00:00
# 1      2234  75208.0  UF2019-1344         61093  2019-10-06 00:00:00
# 2      2755  75231.0  UF2019-1665         62820  2019-12-31 00:00:00
# 3      2110  75228.0  UF2019-1314         60990  2019-09-30 00:00:00
# 4      1663  75051.0  UF2019-1030  59592, 59600  2019-08-04 00:00:00
#
#           time_occured  current_ba off_sex  off_race            hire_date  \
# 0  2020-08-04 22:34:00       11285    Male     White  2017-03-08 00:00:00
# 1  2020-08-04 00:50:00       11208    Male     White  2016-08-24 00:00:00
# 2  2020-08-04 23:37:00        9415    Male     White  2008-04-02 00:00:00
# 3  2020-08-04 18:20:00        9884    Male  Hispanic  2009-06-10 00:00:00
# 4  2020-08-04 00:10:00       10480    Male  Hispanic  2012-09-26 00:00:00
#
#    off_injured                 off_cond_type  off_hospital    service_type  \
# 0        False  No injuries noted or visible         False    Service Call
# 1         True  No injuries noted or visible         False          Arrest
# 2        False  No injuries noted or visible         False          Arrest
# 3        False  No injuries noted or visible         False  Call for Cover
# 4         True  No injuries noted or visible         False          Arrest
#
#                      uof_type       uof_reason cycles_num uof_effective  \
# 0  BD - Tripped, BD - Grabbed  Detention/Frisk        NaN      Yes, Yes
# 1           Held Suspect Down           Arrest        NaN           Yes
# 2              K-9 Deployment           Arrest        NaN           Yes
# 3                 Joint Locks           Arrest        NaN           Yes
# 4   Joint Locks, BD - Grabbed           Arrest        NaN      Yes, Yes
#
#       cit_num  cit_race cit_sex  cit_injured                 cit_cond_type  \
# 0       60833     White    Male        False  No injuries noted or visible
# 1  6020748798  Hispanic  Female         True      Injured prior to contact
# 2       61130     Black    Male         True                          Bite
# 3       26625     White  Female        False  No injuries noted or visible
# 4       59513     Black    Male        False  No injuries noted or visible
#
#    cit_arrest  cit_influence                             cit_charge_type  \
# 0       False       Agitated                                   No Arrest
# 1        True       Agitated                                       APOWW
# 2        True   Poor hygiene           Burglary/Habitation, Warrant/Hold
# 3        True  Unknown Drugs  Assault/FV, Resisting Arrest, Warrant/Hold
# 4        True       Agitated                      Assault/Public Servant
#
#   council_district      ra   beat  sector   division
# 0               D8  6062.0  357.0   350.0  SOUTHEAST
# 1               D1  4160.0  444.0   440.0  SOUTHWEST
# 2               D9  6034.0  247.0   240.0  NORTHEAST
# 3               D9  1132.0  228.0   220.0  NORTHEAST
# 4              NaN     NaN    NaN     NaN        NaN

# %% [markdown]
# For this classification model, we probably also don't need details about the date and time of the incident, so let's get rid of those two columns as well.

# %%
cols_drop2 = ['date_occured', 'time_occured']

# %%
prr_new.drop(cols_drop2, axis = 1, inplace = True)

# %%
prr_new.head()
# Out:
#    objectid      zip     file_num       uof_num  current_ba off_sex  off_race  \
# 0      2817  75253.0  UF2019-1702  62295, 63542       11285    Male     White
# 1      2234  75208.0  UF2019-1344         61093       11208    Male     White
# 2      2755  75231.0  UF2019-1665         62820        9415    Male     White
# 3      2110  75228.0  UF2019-1314         60990        9884    Male  Hispanic
# 4      1663  75051.0  UF2019-1030  59592, 59600       10480    Male  Hispanic
#
#              hire_date  off_injured                 off_cond_type  \
# 0  2017-03-08 00:00:00        False  No injuries noted or visible
# 1  2016-08-24 00:00:00         True  No injuries noted or visible
# 2  2008-04-02 00:00:00        False  No injuries noted or visible
# 3  2009-06-10 00:00:00        False  No injuries noted or visible
# 4  2012-09-26 00:00:00         True  No injuries noted or visible
#
#    off_hospital    service_type                    uof_type       uof_reason  \
# 0         False    Service Call  BD - Tripped, BD - Grabbed  Detention/Frisk
# 1         False          Arrest           Held Suspect Down           Arrest
# 2         False          Arrest              K-9 Deployment           Arrest
# 3         False  Call for Cover                 Joint Locks           Arrest
# 4         False          Arrest   Joint Locks, BD - Grabbed           Arrest
#
#   cycles_num uof_effective     cit_num  cit_race cit_sex  cit_injured  \
# 0        NaN      Yes, Yes       60833     White    Male        False
# 1        NaN           Yes  6020748798  Hispanic  Female         True
# 2        NaN           Yes       61130     Black    Male         True
# 3        NaN           Yes       26625     White  Female        False
# 4        NaN      Yes, Yes       59513     Black    Male        False
#
#                   cit_cond_type  cit_arrest  cit_influence  \
# 0  No injuries noted or visible       False       Agitated
# 1      Injured prior to contact        True       Agitated
# 2                          Bite        True   Poor hygiene
# 3  No injuries noted or visible        True  Unknown Drugs
# 4  No injuries noted or visible        True       Agitated
#
#                               cit_charge_type council_district      ra   beat  \
# 0                                   No Arrest               D8  6062.0  357.0
# 1                                       APOWW               D1  4160.0  444.0
# 2           Burglary/Habitation, Warrant/Hold               D9  6034.0  247.0
# 3  Assault/FV, Resisting Arrest, Warrant/Hold               D9  1132.0  228.0
# 4                      Assault/Public Servant              NaN     NaN    NaN
#
#    sector   division
# 0   350.0  SOUTHEAST
# 1   440.0  SOUTHWEST
# 2   240.0  NORTHEAST
# 3   220.0  NORTHEAST
# 4     NaN        NaN

# %%
prr_new.shape
# Out:
# (2944, 29)

# %%
len(prr_new.objectid.unique())
# Out:
# 2944

# %% [markdown]
# Let's set the objectid to be the index col:

# %%
prr_new.set_index('objectid', inplace = True)

# %%
prr_new.head()
# Out:
#               zip     file_num       uof_num  current_ba off_sex  off_race  \
# objectid
# 2817      75253.0  UF2019-1702  62295, 63542       11285    Male     White
# 2234      75208.0  UF2019-1344         61093       11208    Male     White
# 2755      75231.0  UF2019-1665         62820        9415    Male     White
# 2110      75228.0  UF2019-1314         60990        9884    Male  Hispanic
# 1663      75051.0  UF2019-1030  59592, 59600       10480    Male  Hispanic
#
#                     hire_date  off_injured                 off_cond_type  \
# objectid
# 2817      2017-03-08 00:00:00        False  No injuries noted or visible
# 2234      2016-08-24 00:00:00         True  No injuries noted or visible
# 2755      2008-04-02 00:00:00        False  No injuries noted or visible
# 2110      2009-06-10 00:00:00        False  No injuries noted or visible
# 1663      2012-09-26 00:00:00         True  No injuries noted or visible
#
#           off_hospital    service_type                    uof_type  \
# objectid
# 2817             False    Service Call  BD - Tripped, BD - Grabbed
# 2234             False          Arrest           Held Suspect Down
# 2755             False          Arrest              K-9 Deployment
# 2110             False  Call for Cover                 Joint Locks
# 1663             False          Arrest   Joint Locks, BD - Grabbed
#
#                uof_reason cycles_num uof_effective     cit_num  cit_race  \
# objectid
# 2817      Detention/Frisk        NaN      Yes, Yes       60833     White
# 2234               Arrest        NaN           Yes  6020748798  Hispanic
# 2755               Arrest        NaN           Yes       61130     Black
# 2110               Arrest        NaN           Yes       26625     White
# 1663               Arrest        NaN      Yes, Yes       59513     Black
#
#          cit_sex  cit_injured                 cit_cond_type  cit_arrest  \
# objectid
# 2817        Male        False  No injuries noted or visible       False
# 2234      Female         True      Injured prior to contact        True
# 2755        Male         True                          Bite        True
# 2110      Female        False  No injuries noted or visible        True
# 1663        Male        False  No injuries noted or visible        True
#
#           cit_influence                             cit_charge_type  \
# objectid
# 2817           Agitated                                   No Arrest
# 2234           Agitated                                       APOWW
# 2755       Poor hygiene           Burglary/Habitation, Warrant/Hold
# 2110      Unknown Drugs  Assault/FV, Resisting Arrest, Warrant/Hold
# 1663           Agitated                      Assault/Public Servant
#
#          council_district      ra   beat  sector   division
# objectid
# 2817                   D8  6062.0  357.0   350.0  SOUTHEAST
# 2234                   D1  4160.0  444.0   440.0  SOUTHWEST
# 2755                   D9  6034.0  247.0   240.0  NORTHEAST
# 2110                   D9  1132.0  228.0   220.0  NORTHEAST
# 1663                  NaN     NaN    NaN     NaN        NaN

# %% [markdown]
# Drop cycles_num since it is mostly nans and I don't know what it is:

# %%
prr_new.drop('cycles_num', axis = 1, inplace = True)

# %% [markdown]
# Don't need file_num or uof_num or current_ba

# %%
prr_new.drop('file_num', axis = 1, inplace = True)

# %%
prr_new.drop(['uof_num', 'current_ba'], axis = 1, inplace = True)

# %%
prr_new.drop('division', axis = 1, inplace = True)

# %%
prr_new.drop('council_district', axis = 1, inplace = True)

# %% [markdown]
# ## Metrics Discussion

# %% [markdown]
# We have to think about what our best metric to use in this scenario would be.  This is largely dependant on how I'm going to use this model and who is it aimed towards - of which I'm still not clear....
#
# For now, let's think through what it would mean to misclassify a citizen getting injured in a response to resistance encounter:
# - False positive:  A false positive in this scenario is saying that someone would be labeled as getting injured, when in fact they were not injured (or will not be injured).
# - False negative:  A false negative in this scenario is saying that someone labeled as not getting injured, actually does get injured.
#
# When put simply like this, I think it is more important to reduce false negatives (optimise recall) since you wouldn't want to label someone as not getting hurt, when in fact they would get hurt, given the scenario.  False positives would mean that we're being overly cautious about making sure a citizen is not injured in an encounter of resisting arrest.
#
# So, we'll choose to use recall as our metric.
#
# First, I'm going to have my FSM as a Decision Tree because I have a lot of features and a binary outcome so I am interested in how the model will choose to split on the different features.  I have a feeling I can't have all these string columns though... I've got a bunch of dummying out to do which I don't know how to deal with yet... Let's just give it a go...

# %% [markdown]
# ## FSM 1:  Naive Decision Tree:

# %%
# create variables:
X = prr_new.drop('cit_injured', axis = 1)
y = prr_new.cit_injured

# %%
# train test split:
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 15)

# %%
dtc = DecisionTreeClassifier(max_depth=5, random_state = 42)
dtc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-9083ba3c5baf> in <module>
#       1 dtc = DecisionTreeClassifier(max_depth=5, random_state = 42)
# ----> 2 dtc.fit(X_train, y_train)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     814             sample_weight=sample_weight,
#     815             check_input=check_input,
# --> 816             X_idx_sorted=X_idx_sorted)
#     817         return self
#     818
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/tree/tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     128         random_state = check_random_state(self.random_state)
#     129         if check_input:
# --> 130             X = check_array(X, dtype=DTYPE, accept_sparse="csc")
#     131             y = check_array(y, ensure_2d=False, dtype=None)
#     132             if issparse(X):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     494             try:
#     495                 warnings.simplefilter('error', ComplexWarning)
# --> 496                 array = np.asarray(array, dtype=dtype, order=order)
#     497             except ComplexWarning:
#     498                 raise ValueError("Complex data not supported\n"
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'Male'

# %% [markdown]
# I am not ready for modelling - got to deal with all the string columns first.
